# %% [markdown]
# # LABORATORIO FORMAS CUADRÁTICAS

# %% [markdown]
# ## Sebastian Guayacan Mesa 202014394
#
# ## Andreś Felipe Cordero Martinez 202011880

# %%
from matplotlib import pyplot, pylab, mlab
from pylab import *
from scipy.optimize import linprog
import numpy as np
import math 
from math import factorial
from scipy.optimize import minimize
from matplotlib import cm
import sympy as sym
from itertools import combinations
import pandas as pd
import time
from IPython.display import display

# %% [markdown]
# ### Primer punto
#
# Considere la función cuadrática f(x) = $x^T A_i x$ y las siguientes matrices

# %%
# Crear matrices
A1 = np.array ([[1,0],[0,3]])
A2 = np.array ([[-9,0],[0,-9]])
A3 = np.array ([[1,5],[5,1]])
A4 = np.array ([[5,1],[1,5]])

# %% [markdown]
# # a)
#
# Obtener el contorno

# %%
x1 = np.linspace(-1,1,100)
x2 = np.linspace(-1,1,100)
X1,Y1 = np.meshgrid(x1,x2)

# A1
plt.title("Contorno para matriz A1")
Z = np.matmul(np.matmul(X1[0:2,:].T,A1),X1[0:2,:])
ax=plt.contour(X1,Y1,Z)
plt.colorbar(ax,shrink=0.5,aspect=5)

# %%
# A2

plt.title("Contorno para matriz A2")
Z2 = np.matmul(np.matmul(X1[0:2,:].T,A2),X1[0:2,:])
ax=plt.contour(X1,Y1,Z2)
plt.colorbar(ax,shrink=0.5,aspect=5)

# %%
# A3

plt.title("Contorno para matriz A3")
Z3 = np.matmul(np.matmul(X1[0:2,:].T,A3),X1[0:2,:])
ax=plt.contour(X1,Y1,Z3)
plt.colorbar(ax,shrink=0.5,aspect=5)

# %%
# A4

plt.title("Contorno para matriz A4")
Z4 = np.matmul(np.matmul(X1[0:2,:].T,A4),X1[0:2,:])
ax=plt.contour(X1,Y1,Z4)
plt.colorbar(ax,shrink=0.5,aspect=5)

# %% [markdown]
# # b)
#
# obtener la sperficie de la función

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#
Z1 = Z.reshape(X1.shape)
surf= ax.plot_surface(X1, Y1, Z1,cmap=cm.winter,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.title("Superficie para matriz A1")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# A1
Z22 = Z2.reshape(X1.shape)
surf= ax.plot_surface(X1, Y1, Z22,cmap=cm.winter,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title("Superficie para matriz A2")

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# A1
Z33 = Z3.reshape(X1.shape)
surf= ax.plot_surface(X1, Y1, Z33,cmap=cm.winter,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title("Superficie para matriz A3")

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# A1
Z33 = Z3.reshape(X1.shape)
surf= ax.plot_surface(X1, Y1, Z33,cmap=cm.winter,
                       linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title("Superficie para matriz A4")

plt.show()

# %% [markdown]
# # c)
#
# Obtener los valores y vectores propios de cada matriz

# %%
# Valores y vectores propios de la matriz 
vpA,vcpA = linalg.eig(A1)
print ("Matriz A1: ")
print (f" valores propios: {vpA} \n vectores propios: {vcpA}")
# Out:
# Matriz A1:
#  valores propios: [1. 3.]
#  vectores propios: [[1. 0.]
#  [0. 1.]]

# %%
# Valores y vectores propios de la matriz 
vpA2,vcpA2 = linalg.eig(A2)
print ("Matriz A2: ")
print (f" valores propios: {vpA2} \n vectores propios: {vcpA2}")
# Out:
# Matriz A2:
#  valores propios: [-9. -9.]
#  vectores propios: [[1. 0.]
#  [0. 1.]]

# %%
# Valores y vectores propios de la matriz 
vpA3,vcpA3 = linalg.eig(A3)
print ("Matriz A3: ")
print (f" valores propios: {vpA3} \n vectores propios: {vcpA3}")
# Out:
# Matriz A3:
#  valores propios: [ 6. -4.]
#  vectores propios: [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
# Valores y vectores propios de la matriz 
print ("Matriz A4: ")
vpA4,vcpA4 = linalg.eig(A4)
print (f" valores propios: {vpA4} \n vectores propios: {vcpA4}")
# Out:
# Matriz A4:
#  valores propios: [6. 4.]
#  vectores propios: [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# ### Segundo punto

# %%
# Se creara una funcion que facilitara los calculos y las graficas dependiendo del valor de p
def punto2(p):
  # Se crea la matriz A
  Ap = np.array ([[1,p],[p,1]])
  # Se va a hacer el plot surface entre el rango [-1,1]
  x1 = np.linspace(-1,1,100)
  x2 = np.linspace(-1,1,100)
  X1,Y1 = np.meshgrid(x1,x2)
  # Se realizan las operaciones matriciales correspondientes para encontrar f(x)
  Z = np.matmul(np.matmul(X1[0:2,:].T,Ap),X1[0:2,:])
  # Se crea la variable ax que se utilizara la funcion contourf
  ax=plt.contourf(X1,Y1,Z)
  # Se utiliza el comando colorbar
  plt.colorbar(ax,shrink=0.5,aspect=5)
  plt.title(f"Grafica con función contourf de p = {p}")
  
  # Se crea la figura
  fig = plt.figure()
  # Se agrega un subplot a la figura
  ax = fig.add_subplot(111, projection='3d')
  # Con el valor de Z se calcula la variable auxiliar Z1 necesaria para el plot_surface
  Z1 = Z.reshape(X1.shape)
  # Se realiza el plot_surface con los ejes X, Y y Z
  surf= ax.plot_surface(X1, Y1, Z1,cmap=cm.winter,
                       linewidth=0, antialiased=False)
  # Se utiliza el comando colorbar
  fig.colorbar(surf, shrink=0.5, aspect=5)
  plt.title(f"Grafica con función plot_surface de p = {p}")
  # Se visualiza el plot
  plt.show()  
  
  print(f"Calculo de valores y vectores propios de p = {p}")
  # Se calculan los valores y vectores propios de la matriz Ap 
  vpAp,vcpAp = linalg.eig(Ap)
  # Se imprimen los resultados
  print (f" valores propios: {vpAp} \n vectores propios: {vcpAp}")
  return None

# %% [markdown]
# ###### p = 0

# %%
punto2(0)
# Out:
# Calculo de valores y vectores propios de p = 0
#  valores propios: [1. 1.]
#  vectores propios: [[1. 0.]
#  [0. 1.]]

# %% [markdown]
# ###### p = 0.25

# %%
punto2(0.25)
# Out:
# Calculo de valores y vectores propios de p = 0.25
#  valores propios: [1.25 0.75]
#  vectores propios: [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# ###### p = -0.25

# %%
punto2(-0.25)
# Out:
# Calculo de valores y vectores propios de p = -0.25
#  valores propios: [1.25 0.75]
#  vectores propios: [[ 0.70710678  0.70710678]
#  [-0.70710678  0.70710678]]

# %% [markdown]
# ###### p = 0.75

# %%
punto2(0.75)
# Out:
# Calculo de valores y vectores propios de p = 0.75
#  valores propios: [1.75 0.25]
#  vectores propios: [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# ###### p = -0.75

# %%
punto2(-0.75)
# Out:
# Calculo de valores y vectores propios de p = -0.75
#  valores propios: [1.75 0.25]
#  vectores propios: [[ 0.70710678  0.70710678]
#  [-0.70710678  0.70710678]]

# %% [markdown]
# ###### p = 1

# %%
punto2(1)
# Out:
# Calculo de valores y vectores propios de p = 1
#  valores propios: [2. 0.]
#  vectores propios: [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# ###### p = -1

# %%
punto2(-1)
# Out:
# Calculo de valores y vectores propios de p = -1
#  valores propios: [2. 0.]
#  vectores propios: [[ 0.70710678  0.70710678]
#  [-0.70710678  0.70710678]]

# %% [markdown]
# ###### p = 2

# %%
punto2(2)
# Out:
# Calculo de valores y vectores propios de p = 2
#  valores propios: [ 3. -1.]
#  vectores propios: [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# ###### p = -2

# %%
punto2(-2)
# Out:
# Calculo de valores y vectores propios de p = -2
#  valores propios: [ 3. -1.]
#  vectores propios: [[ 0.70710678  0.70710678]
#  [-0.70710678  0.70710678]]

# %% [markdown]
# ### Tercer punto

# %% [markdown]
# # a)
#
# Obtenga los vectores propios normalizados v1, v2 de la matriz, i.e, |vi| = 1. Grafique en el plano los
# vectores λ1v1 y λ2v2, siendo λi el valor propio asociado al vector vi.

# %%
def vector_valor (vpA,vcpA):
    #multiplicar vector propio 1 con valor propio1
    vect1 = vpA*vcpA[0]
    #multiplicar vector propio 2 con valor propio2
    vect2 = vpA*vcpA[1]
    ax = plt.axes()
    #dibujar los vectores 
    ax.arrow(0,0, vect1[0],vect1[1],color="r", head_width=0.5, head_length=0.5,label = "$ \lambda_1*v_1$")
    ax.arrow(0,0, vect2[0],vect2[1], head_width=0.5, head_length=0.5,label = "$ \lambda_2* v_2$")
    #fijar límites del plano
    plt.xlim(-10,10)
    plt.ylim(-10,10)
    #ubicacion del legend
    plt.legend(loc="best")
    #grilla
    plt.grid()
    #plotear
    plt.show()

# %%
plt.title("Valores propios*Vectores propios matriz A1")
vector_valor(vpA,vcpA)
# Out:
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.title("Valores propios*Vectores propios matriz A2")

vector_valor(vpA2,vcpA2)
# Out:
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.title("Valores propios*Vectores propios matriz A3")
vector_valor(vpA3,vcpA3)
# Out:
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.title("Valores propios*Vectores propios matriz A4")

vector_valor(vpA4,vcpA4)
# Out:
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# # b)
# Grafique dos curvas de contorno de tal manera que estas est´en sobre los vectores

# %%
def graficas (A):

    #valor y vectores propios
    vpA,vcpA = linalg.eig(A)
    #ejes
    x1 = np.linspace(-10,10,100)
    x2 = np.linspace(-10,10,100)
    X1,Y1 = np.meshgrid(x1,x2)

    #  f(x) = x^T A x
    Z = np.matmul(np.matmul(X1[0:2,:].T,A),X1[0:2,:])
    #Contorno de la función
    ax=plt.contour(X1,Y1,Z)
    #multiplicar vector propio 1 con valor propio1
    vect1 = vpA*vcpA[0]
    #multiplicar vector propio 2 con valor propio2
    vect2 = vpA*vcpA[1]
    ax2 = plt.axes()
    #dibujar los vectores 
    ax2.arrow(0,0, vect1[0],vect1[1],color="r", head_width=0.5, head_length=0.5,label = "$ \lambda_1*v_1$", width=0.2)
    ax2.arrow(0,0, vect2[0],vect2[1], head_width=0.5, head_length=0.5,label = "$ \lambda_2* v_2$", width = 0.2)

    plt.legend(loc="best")
    plt.colorbar(ax,shrink=0.5,aspect=5)
    plt.grid()
    plt.show()

# %%
plt.title("Matriz A1")

graficas(A1)
# Out:
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.title("Matriz A2")

graficas(A2)
# Out:
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.title("Matriz A3")

graficas(A3)
# Out:
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.title("Matriz A4")
graficas(A4)
# Out:
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ### Cuarto Punto

# %%
# Se va a hacer el plot surface entre el rango [-1,1]
x1 = np.linspace(-1,1,100)
x2 = np.linspace(-1,1,100)
X1,Y1 = np.meshgrid(x1,x2)
# Se reemplaza Z con la función q
Z = 4*(X1**2) + 2*X1*Y1 - 3*(Y1**2) 
# Se crea la variable ax que se utilizara la funcion contourF
ax=plt.contourf(X1,Y1,Z)
# Se utiliza el comando colorbar
plt.colorbar(ax,shrink=0.5,aspect=5)
plt.title("Grafica con función contourf")

# Se crea la figura
fig = plt.figure()
# Se agrega un subplot a la figura
ax = fig.add_subplot(111, projection='3d')
# Con el valor de Z se calcula la variable auxiliar Z1 necesaria para el plot_surface
Z1 = Z.reshape(X1.shape)
# Se realiza el plot_surface con los ejes X, Y y Z
surf= ax.plot_surface(X1, Y1, Z1,cmap=cm.winter,
                     linewidth=0, antialiased=False)
# Se utiliza el comando colorbar
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title("Grafica con función plot_surface")
# Se visualiza el plot
plt.show()

# Se crea la variable ax que se utilizara la funcion contour
ax=plt.contour(X1,Y1,Z)
# Se utiliza el comando colorbar
plt.colorbar(ax,shrink=0.5,aspect=5)
plt.title("Grafica con función contour")
# Out:
# Text(0.5, 1.0, 'Grafica con función contour')

# %%
# Se escribe la matriz A
A41 = np.array([[4,1],[1,-3]])
# Se utiliza la función realizada en el punto 3
plt.title("Punto 4 con la función del punto 3")
graficas(A41)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# ### Quinto Punto
#
# Cree 2 funciones polinomiales de orden 2 qi(x, y), i = 1, 2 tal que qi(x, y) = 0 ∀(x, y) ∈ Bd D la frontera de la
#  egión D, región definida como:
#
#  D = $\frac{x^2}{4}+ \frac {y^2}{9} <= 25$

# %%
def polinomios (A,Z1):
    plt.title("Contorno y valores propios*vectores propios")
    graficas(A)


    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    # A1
    Z51 = Z1.reshape(X1.shape)
    #plotear en 3D la superficie
    surf= ax.plot_surface(X1, Y1, Z51,cmap=cm.winter,
                        linewidth=0, antialiased=False)
    fig.colorbar(surf, shrink=0.5, aspect=5)
    
    plt.title("Superficie polinomio")
    plt.show()

    # plotear el contourf 
    ax2=plt.contourf(X1,Y1,Z1)
    plt.title("Contourf polinomio")
    plt.colorbar(ax2,shrink=0.5,aspect=5)

# %% [markdown]
# Las funciones obtenidas son:
#
# ## q1 = $\frac{x^2}{4}+ \frac {y^2}{9} - 25$
#
# ## q2 = $-\frac{x^2}{4}- \frac {y^2}{9} + 25$

# %%
# Primer polinomio
A1=np.array([[(1/4),0],[0,(1/9)]])
print ("Matriz A1: ")
vpA4,vcpA4 = linalg.eig(A1)
print (f" valores propios: {vpA4} \n vectores propios: {vcpA4}")
Z1 = (1/4)*X1**2 + (1/9)*Y1**2 -25   
polinomios(A1,Z1)
# Out:
# Matriz A1:
#  valores propios: [0.25       0.11111111]
#  vectores propios: [[1. 0.]
#  [0. 1.]]
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Segundo polinomio
A1=np.array([[(-1/4),0],[0,(-1/9)]])
print ("Matriz A1: ")
vpA4,vcpA4 = linalg.eig(A1)
print (f" valores propios: {vpA4} \n vectores propios: {vcpA4}")
Z1 = -(1/4)*X1**2 - (1/9)*Y1**2 +25   
polinomios(A1,Z1)
# Out:
# Matriz A1:
#  valores propios: [-0.25       -0.11111111]
#  vectores propios: [[1. 0.]
#  [0. 1.]]
# /home/asus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
